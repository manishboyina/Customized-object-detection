# %%
# mount drive with colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os      ## changing the directory
os.chdir('/content/drive/My Drive/yolo')

# %%
# !unzip "/content/drive/My Drive/yolo/yolo_custom.zip"      ## unzip the yolo file
# Out:
# Archive:  /content/drive/My Drive/yolo/yolo_custom.zip
# replace darknet-master/.gitignore? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: darknet-master/.gitignore
#   inflating: darknet-master/cfg/alexnet.cfg
#   inflating: darknet-master/cfg/cifar.cfg
#   inflating: darknet-master/cfg/cifar.test.cfg
#   inflating: darknet-master/cfg/coco.data
#   inflating: darknet-master/cfg/combine9k.data
#   inflating: darknet-master/cfg/darknet.cfg
#   inflating: darknet-master/cfg/darknet19.cfg
#   inflating: darknet-master/cfg/darknet19_448.cfg
#   inflating: darknet-master/cfg/darknet53.cfg
#   inflating: darknet-master/cfg/darknet53_448.cfg
#   inflating: darknet-master/cfg/darknet9000.cfg
#   inflating: darknet-master/cfg/densenet201.cfg
#   inflating: darknet-master/cfg/extraction.cfg
#   inflating: darknet-master/cfg/extraction.conv.cfg
#   inflating: darknet-master/cfg/extraction22k.cfg
#   inflating: darknet-master/cfg/go.cfg
#   inflating: darknet-master/cfg/go.test.cfg
# ...

# %%
# %cd /content/drive/My Drive/yolo/darknet-master      ## getting into darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/drive/My Drive/yolo/darknet-master
# make: Nothing to be done for 'all'.

# %%
# !sudo apt install dos2unix       ## converting docs to unix file for training purpose
# !dos2unix ./data/train.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3_custom_train.cfg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/yolo.data to Unix format...
# dos2unix: converting file ./data/yolo.names to Unix format...
# dos2unix: converting file ./cfg/yolov3_custom_train.cfg to Unix format...

# %%
# %cd /content/drive/My Drive/yolo/darknet-master
# Out:
# /content/drive/My Drive/yolo/darknet-master

# %%
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg darknet53.conv.74    ## train the custom weights
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 82 Avg IOU: 0.614845, Class: 0.988797, Obj: 0.453792, No Obj: 0.002587, .5R: 1.000000, .75R: 0.250000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000018, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.132903, Class: 0.718744, Obj: 0.000019, No Obj: 0.000007, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 82 Avg IOU: 0.743753, Class: 0.998125, Obj: 0.610474, No Obj: 0.001573, .5R: 1.000000, .75R: 0.500000,  count: 2
# Region 94 Avg IOU: 0.544082, Class: 0.682681, Obj: 0.331066, No Obj: 0.000595, .5R: 0.666667, .75R: 0.000000,  count: 6
# Region 106 Avg IOU: 0.534025, Class: 0.591897, Obj: 0.012545, No Obj: 0.000026, .5R: 0.666667, .75R: 0.000000,  count: 3
# Region 82 Avg IOU: 0.690724, Class: 0.993479, Obj: 0.599419, No Obj: 0.001998, .5R: 1.000000, .75R: 0.333333,  count: 3
# ...

# %% [markdown]
# ### As the colab crashes for 12hrs in safe side i have take the backup file after 1000 iterations and restarted colab with yolov3_custom_train.backup and continued for 3000 iterations.

# %%
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg backup/yolov3_custom_train.backup
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.831791, Class: 0.999720, Obj: 0.810963, No Obj: 0.002582, .5R: 1.000000, .75R: 0.800000,  count: 5
# Region 94 Avg IOU: 0.649434, Class: 0.996102, Obj: 0.720794, No Obj: 0.000124, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.827604, Class: 0.999582, Obj: 0.942747, No Obj: 0.001623, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.832741, Class: 0.998123, Obj: 0.981932, No Obj: 0.001692, .5R: 1.000000, .75R: 1.000000,  count: 4
# ...
